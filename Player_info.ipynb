# %%
# %matplotlib notebook

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem
# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')
import csv

# %%
players20_data = "Resources/players_20.csv"

# %%
players20_datadf = pd.read_csv(players20_data, header=0)

# %%
New_players20_data= players20_datadf[["sofifa_id","short_name","long_name", "nationality", "age", "dob",
                                      "height_in","weight_lb", "club" ]]
New_players20_data
# Out:
#        sofifa_id         short_name                            long_name  \
# 0         158023           L. Messi       Lionel Andrés Messi Cuccittini
# 1          20801  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 2         190871          Neymar Jr        Neymar da Silva Santos Junior
# 3         200389           J. Oblak                            Jan Oblak
# 4         183277          E. Hazard                          Eden Hazard
# ...          ...                ...                                  ...
# 18273     245006         Shao Shuai                                   邵帅
# 18274     250995       Xiao Mingjie                         Mingjie Xiao
# 18275     252332          Zhang Wei                                   张威
# 18276     251110       Wang Haijian                                  汪海健
# 18277     233449         Pan Ximing                                  潘喜明
#
#       nationality  age        dob  height_in  weight_lb  \
# ...

# %%
#df = df.rename(columns={'oldName1': 'newName1', 'oldName2': 'newName2'})-Rename Columns
#New_players20_dataC= New_players20_data.rename(columns={"short_name": "Alias","long_name": "Name", 
                                                      #  "nationality": "Nationality", "age": "Age", "dob": "DOB",
                                      #"height_in": "Height","weight_lb": "Weight", "club": "Club"})
#New_players20_dataC
# Out:
#                    Alias                                 Name Nationality  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   Argentina
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro    Portugal
# 2              Neymar Jr        Neymar da Silva Santos Junior      Brazil
# 3               J. Oblak                            Jan Oblak    Slovenia
# 4              E. Hazard                          Eden Hazard     Belgium
# ...                  ...                                  ...         ...
# 18273         Shao Shuai                                   邵帅    China PR
# 18274       Xiao Mingjie                         Mingjie Xiao    China PR
# 18275          Zhang Wei                                   张威    China PR
# 18276       Wang Haijian                                  汪海健    China PR
# 18277         Pan Ximing                                  潘喜明    China PR
#
#        Age        DOB  Height  Weight                           Club
# ...

# %%
New_players20_data.to_csv("Resources/New_Player20.csv")
